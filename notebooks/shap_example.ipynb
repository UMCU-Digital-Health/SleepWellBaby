# %% [markdown]
# # Example
# This notebook illustrates how the sleepwellbaby package can be used to get sleep state predictions using mock data.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd

from sleepwellbaby.model import load_model
from sleepwellbaby.data import (
    compute_reference_values,
    generate_mock_signalbase_data,
)
from sleepwellbaby.utils import get_swb_predictions, shap
from sleepwellbaby.preprocess import pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Prepare data
# Generate some mock data (same format as SignalBase with 1Hz). If you want to use 0.4Hz set `freq=2s500ms`.

# %%
df = generate_mock_signalbase_data(freq='S').sort_values(by='datetime').set_index('datetime')

# %% [markdown]
# Compute reference values using rolling windows

# %%
df = compute_reference_values(df, freq=1)

# %% [markdown]
# ## Get predictions
# We make a prediction every one minute in the below example.
#
# *Note*: we start 8 minutes later than our dataframe otherwise we get a ValueError in `get_swb_predictions`.

# %%
# Get indices of times at which you want to get an SWB value (we only compute it at whole minutes)
t_range_swb = pd.date_range(
    start=(df.index.min().round(freq='min') + pd.Timedelta(minutes=8)),
    end=df.index.max().round(freq='min'),
    freq='1min'
)

# %% [markdown]
# Return predictions (takes a couple of minutes for a single day with one prediction every minute)

# %%
payloads = shap(df, t_range_swb, birth_date="2000-01-01", gestation_period=210, freq='S')
# Out:
# Calculating SWB: 100%|██████████| 2873/2873 [00:08<00:00, 330.82it/s]

# %% [markdown]
# Drop rows without a prediction

# %%
payloads = np.array(payloads)
mask = [x is not None for x in payloads]
payloads[mask]

model, model_support_dict = load_model()
dfs = [pipeline(p, model_support_dict) for p in payloads[mask][:100]]
df = pd.concat(dfs)

# %%
df
# Out:
#     HR__0_120__median  HR__0_120__mean  HR__0_120__variance  \
# 0            0.120394         0.235572             0.749809
# 0            0.173177         0.137855             0.780982
# 0            0.112393         0.025206             0.897659
# 0           -0.169907         0.064088             0.901172
# 0            0.137341         0.124580             0.810317
# ..                ...              ...                  ...
# 0            0.366417         0.126996             1.151989
# 0           -0.189784        -0.097743             1.009706
# 0           -0.216787        -0.076386             0.776068
# 0           -0.228110        -0.175331             0.735894
# 0           -0.196487        -0.265778             0.790140
#
#     HR__0_120__maximum  HR__0_120__minimum  \
# 0             2.205438           -1.376022
# 0             1.898651           -1.543657
# 0             1.897466           -1.692563
# 0             2.077222           -1.695403
# 0             2.077134           -1.933647
# ..                 ...                 ...
# 0             1.646811           -2.715009
# 0             1.640034           -1.937780
# 0             1.737867           -1.590518
# 0             1.780446           -2.146330
# 0             1.781287           -2.145722
#
#     HR__0_120__linear_trend__attr_"pvalue"  \
# 0                                 0.664039
# 0                                 0.152735
# 0                                 0.852549
# 0                                 0.509057
# 0                                 0.473429
# ..                                     ...
# 0                                 0.772240
# 0                                 0.867195
# 0                                 0.183941
# 0                                 0.199590
# 0                                 0.259648
#
#     HR__0_120__linear_trend__attr_"rvalue"  \
# 0                                -0.064323
# 0                                -0.209618
# 0                                -0.027549
# 0                                -0.097653
# 0                                 0.105979
# ..                                     ...
# 0                                -0.042889
# 0                                 0.024786
# 0                                 0.195078
# 0                                -0.188448
# 0                                 0.165944
#
#     HR__0_120__linear_trend__attr_"intercept"  \
# 0                                    0.330054
# 0                                    0.452095
# 0                                    0.069482
# 0                                    0.221342
# 0                                   -0.037250
# ..                                        ...
# 0                                    0.205084
# 0                                   -0.139992
# 0                                   -0.367906
# 0                                    0.098897
# 0                                   -0.515999
#
#     HR__0_120__linear_trend__attr_"slope"  HR__0_240__median  ...  \
# 0                               -0.004021          -0.053821  ...
# 0                               -0.013372           0.047710  ...
# 0                               -0.001884           0.116683  ...
# 0                               -0.006692           0.120252  ...
# 0                                0.006886           0.111383  ...
# ..                                    ...                ...  ...
# 0                               -0.003323           0.454402  ...
# 0                                0.001798           0.277223  ...
# 0                                0.012405           0.023030  ...
# 0                               -0.011669          -0.222421  ...
# 0                                0.010648          -0.211554  ...
#
#     RR__0_480__linear_trend__attr_"slope"  RR__0_60__median  RR__0_60__mean  \
# 0                                0.000589          0.011137        0.036788
# 0                               -0.001536         -0.448352       -0.372965
# 0                               -0.003230         -0.666427       -0.488510
# 0                               -0.002429          0.053261       -0.100262
# 0                                0.000248          0.527417        0.342590
# ..                                    ...               ...             ...
# 0                                0.000808         -0.016547       -0.014579
# 0                                0.001314          0.413318        0.157265
# 0                                0.001639          0.178168        0.210424
# 0                                0.000509         -0.312645       -0.250993
# 0                               -0.000393         -0.120300       -0.031184
#
#     RR__0_60__variance  RR__0_60__maximum  RR__0_60__minimum  \
# 0             0.893154           1.657312          -2.280842
# 0             0.888254           1.430271          -2.300612
# 0             1.023420           1.461642          -1.965262
# 0             1.050770           1.152903          -2.652325
# 0             0.572308           1.822344          -1.108488
# ..                 ...                ...                ...
# 0             1.051328           1.460169          -1.952650
# 0             0.884381           1.880411          -2.033231
# 0             0.601548           1.836385          -1.520900
# 0             0.835339           1.545283          -2.168287
# 0             0.974238           2.290783          -2.168735
#
#     RR__0_60__linear_trend__attr_"pvalue"  \
# 0                                0.258116
# 0                                0.619434
# 0                                0.012059
# 0                                0.117784
# 0                                0.755020
# ..                                    ...
# 0                                0.363587
# 0                                0.391416
# 0                                0.789603
# 0                                0.129361
# 0                                0.301770
#
#     RR__0_60__linear_trend__attr_"rvalue"  \
# 0                                0.240259
# 0                                0.106789
# 0                               -0.503875
# 0                               -0.327883
# 0                               -0.067208
# ..                                    ...
# 0                                0.194045
# 0                               -0.183239
# 0                               -0.057490
# 0                               -0.318456
# 0                               -0.219934
#
#     RR__0_60__linear_trend__attr_"intercept"  \
# 0                                  -0.340435
# 0                                  -0.540170
# 0                                   0.358335
# 0                                   0.458115
# 0                                   0.427058
# ..                                       ...
# 0                                  -0.345120
# 0                                   0.443546
# 0                                   0.284500
# 0                                   0.232550
# 0                                   0.329460
#
#     RR__0_60__linear_trend__attr_"slope"
# 0                               0.032802
# 0                               0.014540
# 0                              -0.073639
# 0                              -0.048554
# 0                              -0.007345
# ..                                   ...
# 0                               0.028743
# 0                              -0.024894
# 0                              -0.006441
# 0                              -0.042047
# 0                              -0.031360
#
# [100 rows x 108 columns]

# %%
df.tail(10)

# %% [markdown]
# #
